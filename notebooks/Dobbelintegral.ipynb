# %% [markdown]
# # Eksempel 2.15 Vector Calculus
#
# Finn flateintegralet
#
# $$
# \int \vec{r}\cdot{n}d\sigma
# $$
#
# når
#
# $$
# \vec{r}=x\mathbf{i} + y\mathbf{j} + (1-x^2-y^2)\mathbf{k}
# $$
#
# og $x^2+y^2 < 1$.
#
# Vi kan gå analytisk til verks som i VC s 37 og finne at integralet tilsvarer
#
# $$
# \begin{align}
# \int \vec{r}\cdot{n}d\sigma &= \int_{-1}^1 \int_{-\sqrt{1-x^2}}^{\sqrt{1-x^2}} \vec{r} \cdot \frac{\partial \vec{r}}{\partial x} \times \frac{\partial \vec{r}}{\partial y} dy dx \\
# &=  \int_{-1}^1\int_{-\sqrt{1-x^2}}^{\sqrt{1-x^2}}1+x^2+y^2dydx
# \end{align}
# $$
#
# Dobbeltintegralet implementeres først eksakt i sympy som to itererte integraler, først i $y$-retning, så i $x$-retning.

# %%
import sympy as sp
x, y = sp.symbols('x,y')
f = 1+x**2+y**2
II = sp.integrate(sp.integrate(f, (y, -sp.sqrt(1-x**2), sp.sqrt(1-x**2))), (x, -1, 1))
print('Svaret er', II)
# Out:
# Svaret er 3*pi/2

# %% [markdown]
# Men merk at vi kunne egentlig ha gjort all matematikken i sympy, og vi trenger derfor kun
#
# $$
# \int \vec{r}\cdot{n}d\sigma = \int_{-1}^1 \int_{-\sqrt{1-x^2}}^{\sqrt{1-x^2}} \vec{r} \cdot \frac{\partial \vec{r}}{\partial x} \times \frac{\partial \vec{r}}{\partial y} dy dx
# $$

# %%
from sympy.vector import CoordSys3D
N = CoordSys3D('N')
r = x*N.i + y*N.j + (1-x**2-y**2)*N.k
drdx = r.diff(x, 1)
drdy = r.diff(y, 1)
n = drdx.cross(drdy)
II2 = sp.integrate(sp.integrate(r.dot(n), (y, -sp.sqrt(1-x**2), sp.sqrt(1-x**2))), (x, -1, 1))
print('Svaret er fremdeles', II2)
# Out:
# Svaret er fremdeles 3*pi/2

# %% [markdown]
# Vi kan også beregne dobbeltintegralet numerisk ved å bruke [scipy.integrate.dblquad](https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.dblquad.html)

# %%
import numpy as np
from scipy.integrate import dblquad
a = dblquad(lambda x, y: 1+x**2+y**2, -1, 1, lambda x: -np.sqrt(1-x**2), lambda x: np.sqrt(1-x**2))
print('Numerisk resultat', a[0])
# Out:
# Numerisk resultat 4.712388980384572

# %% [markdown]
# Areal

# %%
r = x*N.i + y*N.j + (6-0.1*(x**2+y**2))*N.k
drdx = r.diff(x, 1)
drdy = r.diff(y, 1)
n = drdx.cross(drdy)
nl = sp.sqrt(n.dot(n))
hh = sp.integrate(nl, (y, -sp.sqrt(16-x**2), sp.sqrt(16-x**2)))
print(hh.simplify())
# Out:
# 1.0*(0.008*x**4*sqrt(-0.04*x**2 + polar_lift(0.04*x**2 + 1) + 0.64)*asinh(0.2*sqrt(16 - x**2)/sqrt(polar_lift(0.04*x**2 + 1))) + 0.4*x**2*sqrt(-0.04*x**2 + polar_lift(0.04*x**2 + 1) + 0.64)*asinh(0.2*sqrt(16 - x**2)/sqrt(polar_lift(0.04*x**2 + 1))) + 1.64*sqrt(16 - x**2)*polar_lift(0.04*x**2 + 1) + 5.0*sqrt(-0.04*x**2 + polar_lift(0.04*x**2 + 1) + 0.64)*asinh(0.2*sqrt(16 - x**2)/sqrt(polar_lift(0.04*x**2 + 1))))/((0.04*x**2 + 1.0)*sqrt(-0.04*x**2 + polar_lift(0.04*x**2 + 1) + 0.64))

# %%
A = sp.integrate(hh.simplify(), (x, -4, 4))
print(A)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a08d13a82581> in <module>
# ----> 1 A = sp.integrate(hh.simplify(), (x, -4, 4))
#       2 print(A)
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1475
#    1476     if isinstance(integral, Integral):
# -> 1477         return integral.doit(**doit_flags)
#    1478     else:
#    1479         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     538                     antideriv = None
#     539                 else:
# --> 540                     antideriv = self._eval_integral(
#     541                         function, xab[0], **eval_kwargs)
#     542                     if antideriv is None and meijerg is True:
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds)
#     996                     try:
#     997                         if conds == 'piecewise':
# --> 998                             h = heurisch_wrapper(g, x, hints=[])
#     999                         else:
#    1000                             h = heurisch_(g, x, hints=[])
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     129         return f*x
#     130
# --> 131     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
#     132                    unnecessary_permutations)
#     133     if not isinstance(res, Basic):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations)
#     700
#     701     if not (F.free_symbols - set(V)):
# --> 702         solution = _integrate('Q')
#     703
#     704         if solution is None:
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/heurisch.py in _integrate(field)
#     654         # revise this code.
#     655         candidate = poly_part/poly_denom + Add(*log_part) + Add(*atan_part)
# --> 656         h = F - _derivation(candidate) / denom
#     657         raw_numer = h.as_numer_denom()[0]
#     658
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/heurisch.py in _derivation(h)
#     479     numers = [ cancel(denom*g) for g in diffs ]
#     480     def _derivation(h):
# --> 481         return Add(*[ d * h.diff(v) for d, v in zip(numers, V) ])
#     482
#     483     def _deflation(p):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/integrals/heurisch.py in <listcomp>(.0)
#     479     numers = [ cancel(denom*g) for g in diffs ]
#     480     def _derivation(h):
# --> 481         return Add(*[ d * h.diff(v) for d, v in zip(numers, V) ])
#     482
#     483     def _deflation(p):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3093     def diff(self, *symbols, **assumptions):
#    3094         assumptions.setdefault("evaluate", True)
# -> 3095         return Derivative(self, *symbols, **assumptions)
#    3096
#    3097     ###########################################################################
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1390             # object, the default in `Basic` will call a loop over
#    1391             # `_eval_derivative`:
# -> 1392             obj = expr._eval_derivative_n_times(v, count)
#    1393             if obj is not None and obj.is_zero:
#    1394                 return obj
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/basic.py in _eval_derivative_n_times(self, s, n)
#    1680             obj = self
#    1681             for i in range(n):
# -> 1682                 obj2 = obj._accept_eval_derivative(s)
#    1683                 if obj == obj2 or obj2 is None:
#    1684                     break
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/basic.py in _accept_eval_derivative(self, s)
#    1656     def _accept_eval_derivative(self, s):
#    1657         # This method needs to be overridden by array-like objects
# -> 1658         return s._visit_eval_derivative_scalar(self)
#    1659
#    1660     def _visit_eval_derivative_scalar(self, base):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/basic.py in _visit_eval_derivative_scalar(self, base)
#    1661         # Base is a scalar
#    1662         # Types are (base: scalar, self: scalar)
# -> 1663         return base._eval_derivative(self)
#    1664
#    1665     def _visit_eval_derivative_array(self, base):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/add.py in _eval_derivative(self, s)
#     392     @cacheit
#     393     def _eval_derivative(self, s):
# --> 394         return self.func(*[a.diff(s) for a in self.args])
#     395
#     396     def _eval_nseries(self, x, n, logx):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/add.py in <listcomp>(.0)
#     392     @cacheit
#     393     def _eval_derivative(self, s):
# --> 394         return self.func(*[a.diff(s) for a in self.args])
#     395
#     396     def _eval_nseries(self, x, n, logx):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3093     def diff(self, *symbols, **assumptions):
#    3094         assumptions.setdefault("evaluate", True)
# -> 3095         return Derivative(self, *symbols, **assumptions)
#    3096
#    3097     ###########################################################################
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1390             # object, the default in `Basic` will call a loop over
#    1391             # `_eval_derivative`:
# -> 1392             obj = expr._eval_derivative_n_times(v, count)
#    1393             if obj is not None and obj.is_zero:
#    1394                 return obj
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/mul.py in _eval_derivative_n_times(self, s, n)
#     916             terms = []
#     917             for kvals, c in multinomial_coefficients_iterator(m, n):
# --> 918                 p = prod([arg.diff((s, k)) for k, arg in zip(kvals, args)])
#     919                 terms.append(c * p)
#     920             return Add(*terms)
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/mul.py in <listcomp>(.0)
#     916             terms = []
#     917             for kvals, c in multinomial_coefficients_iterator(m, n):
# --> 918                 p = prod([arg.diff((s, k)) for k, arg in zip(kvals, args)])
#     919                 terms.append(c * p)
#     920             return Add(*terms)
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3093     def diff(self, *symbols, **assumptions):
#    3094         assumptions.setdefault("evaluate", True)
# -> 3095         return Derivative(self, *symbols, **assumptions)
#    3096
#    3097     ###########################################################################
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1390             # object, the default in `Basic` will call a loop over
#    1391             # `_eval_derivative`:
# -> 1392             obj = expr._eval_derivative_n_times(v, count)
#    1393             if obj is not None and obj.is_zero:
#    1394                 return obj
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/basic.py in _eval_derivative_n_times(self, s, n)
#    1680             obj = self
#    1681             for i in range(n):
# -> 1682                 obj2 = obj._accept_eval_derivative(s)
#    1683                 if obj == obj2 or obj2 is None:
#    1684                     break
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/basic.py in _accept_eval_derivative(self, s)
#    1656     def _accept_eval_derivative(self, s):
#    1657         # This method needs to be overridden by array-like objects
# -> 1658         return s._visit_eval_derivative_scalar(self)
#    1659
#    1660     def _visit_eval_derivative_scalar(self, base):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/basic.py in _visit_eval_derivative_scalar(self, base)
#    1661         # Base is a scalar
#    1662         # Types are (base: scalar, self: scalar)
# -> 1663         return base._eval_derivative(self)
#    1664
#    1665     def _visit_eval_derivative_array(self, base):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/add.py in _eval_derivative(self, s)
#     392     @cacheit
#     393     def _eval_derivative(self, s):
# --> 394         return self.func(*[a.diff(s) for a in self.args])
#     395
#     396     def _eval_nseries(self, x, n, logx):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/add.py in <listcomp>(.0)
#     392     @cacheit
#     393     def _eval_derivative(self, s):
# --> 394         return self.func(*[a.diff(s) for a in self.args])
#     395
#     396     def _eval_nseries(self, x, n, logx):
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3093     def diff(self, *symbols, **assumptions):
#    3094         assumptions.setdefault("evaluate", True)
# -> 3095         return Derivative(self, *symbols, **assumptions)
#    3096
#    3097     ###########################################################################
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1390             # object, the default in `Basic` will call a loop over
#    1391             # `_eval_derivative`:
# -> 1392             obj = expr._eval_derivative_n_times(v, count)
#    1393             if obj is not None and obj.is_zero:
#    1394                 return obj
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/mul.py in _eval_derivative_n_times(self, s, n)
#     916             terms = []
#     917             for kvals, c in multinomial_coefficients_iterator(m, n):
# --> 918                 p = prod([arg.diff((s, k)) for k, arg in zip(kvals, args)])
#     919                 terms.append(c * p)
#     920             return Add(*terms)
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/mul.py in prod(a, start)
#    1730
#    1731     """
# -> 1732     return reduce(operator.mul, a, start)
#    1733
#    1734
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/decorators.py in __sympifyit_wrapper(a, b)
#      89                 if not hasattr(b, '_op_priority'):
#      90                     b = sympify(b, strict=True)
# ---> 91                 return func(a, b)
#      92             except SympifyError:
#      93                 return retval
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/decorators.py in binary_op_wrapper(self, other)
#     127                     if f is not None:
#     128                         return f(self)
# --> 129             return func(self, other)
#     130         return binary_op_wrapper
#     131     return priority_decorator
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/expr.py in __mul__(self, other)
#     149     @call_highest_priority('__rmul__')
#     150     def __mul__(self, other):
# --> 151         return Mul(self, other)
#     152
#     153     @_sympifyit('other', NotImplemented)
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      47         c_part, nc_part, order_symbols = cls.flatten(args)
#      48         is_commutative = not nc_part
# ---> 49         obj = cls._from_args(c_part + nc_part, is_commutative)
#      50         obj = cls._exec_constructor_postprocessors(obj)
#      51
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/operations.py in _from_args(cls, args, is_commutative)
#      62             return args[0]
#      63
# ---> 64         obj = super(AssocOp, cls).__new__(cls, *args)
#      65         if is_commutative is None:
#      66             is_commutative = fuzzy_and(a.is_commutative for a in args)
#
# ~/opt/anaconda3/envs/mek1100/lib/python3.8/site-packages/sympy/core/basic.py in __new__(cls, *args)
#      97         obj = object.__new__(cls)
#      98         obj._assumptions = cls.default_assumptions
# ---> 99         obj._mhash = None  # will be set by __hash__ method.
#     100
#     101         obj._args = args  # all items in args must be Basic objects
#
# KeyboardInterrupt:
