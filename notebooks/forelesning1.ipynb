# %% [markdown]
# # <center>Kapittel 1 - Felt i naturen, skalar- og vektorfelt, skalering</center>
#
# ## Mål
#
# * Forstå skalarer og vektorer
# * Lære å addere og subtrahere vektorer, geometrisk og algebraisk
# * Utforske bruk av vektorer i Geogebra

# %% [markdown]
# # <center>Felter</center>
#
# <center>I fysikken snakker vi om felter: Temperatur, tetthet, momentum, elektriske og magnetiske felt</center>
#
# <center>Et felt kan være en skalar, eller en vektor. En skalar kjennetegnes kun av sin éne verdi (temperatur, trykk), mens en vektor har både størrelse og retning (hastighet). Nedbørsmengde i figuren under er en skalar. Vinden har både hastighet og retning og er representert med vektorer.</center>
#
#
# <center><img src='../figs/hurrycanefloyd.png' alt='Hurrycane Floyd' width='600' height='600'></center>

# %% [markdown]
# # <center>Vektorer og punkter</center>
#
# Vektorer og punkter beskrives begge av to tall i 2D og 3 tall i 3D. Men en vektor kan starte fra hvor som helst. Selve vektoren er kun beskrevet av sin lengde og retning.
#
# ![vektorogpunkt.png](attachment:vektorogpunkt.png)

# %% [markdown]
# # Vektorer og punkter
#
# $$
# \begin{equation*}
# u(x,y,z) = u_x \boldsymbol{i} + u_y \boldsymbol{j} + u_z \boldsymbol{k}
# \end{equation*}
# $$
#
# ![vektorogpunkt2.png](attachment:vektorogpunkt2.png)

# %%
# %%HTML
# <iframe src='https://www.geogebra.org/m/jmmdrnst' width='800' height='600'></iframe>
# Out:
# <iframe src='https://www.geogebra.org/m/jmmdrnst' width='800' height='600'></iframe>
